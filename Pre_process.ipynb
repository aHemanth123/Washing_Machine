# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\Hemanth2512005\Desktop\Washing_machine_Sql project\Washingmachine.csv')

# %%
data
# Out:
#                                            Product Name    Price  Ratings  \
# 0     SAMSUNG 7 kg Diamond Drum feature Fully Automa...  ₹15,790      4.3
# 1     realme TechLife 7 kg Semi Automatic Top Load W...   ₹7,790      4.2
# 2     realme TechLife 7.5 kg 5 Star Rating Fabric Sa...  ₹12,290      4.2
# 3     LG 7 kg 5 star rating and Wind jet dry Semi Au...  ₹11,990      4.5
# 4     SAMSUNG 6 kg 5 Star With Hygiene Steam and Cer...  ₹22,990      4.4
# ...                                                 ...      ...      ...
# 1051  SAMSUNG 8 kg Inverter 5 Star with Ecobubble Te...  ₹19,990      4.3
# 1052  SAMSUNG 6 kg 5 star with Center Jet Technology...   ₹8,990      4.4
# 1053  ONIDA 7 kg Semi Automatic Top Load Washing Mac...   ₹7,990      4.2
# 1054  Whirlpool 6 kg Magic Clean 5 Star Semi Automat...   ₹8,990      4.4
# 1055  SAMSUNG 6.5 kg Inverter 5 star Wobble Technolo...  ₹16,990      4.4
#
#            Brand Name                   Model Name Washing Capacity  \
# ...

# %%
data.isnull().sum()
# Out:
# Product Name          0
# Price                 0
# Ratings               0
# Brand Name            0
# Model Name            0
# Washing Capacity      0
# Color                 0
# Maximum Spin Speed    0
# Function Type         0
# Inbuilt Heater        0
# Washing Method        0
# Product_Url           0
# dtype: int64

# %%
n = data.duplicated().sum()
print(n)
# Out:
# 0

# %%
data.shape
# Out:
# (1056, 12)

# %%
data['Brand Name'].unique()
# Out:
# array(['SAMSUNG', 'realme TechLife', 'LG', 'Haier', 'MarQ by Flipkart',
#        'Whirlpool', 'IFB', 'ONIDA', 'Midea'], dtype=object)

# %%
data['Color'].unique()
# Out:
# array(['Silver', 'White, Black', 'Grey', 'Grey, White', 'White',
#        'Brown, Grey', 'Multicolor', 'White, Maroon', 'Grey, Black',
#        'White, Blue', 'Blue, White', 'Black, Grey', 'White, Grey, Purple',
#        'Grey, Purple'], dtype=object)

# %%
data['Function Type'].unique()
# Out:
# array(['Fully Automatic Top Load', 'Semi Automatic Top Load',
#        'Fully Automatic Front Load'], dtype=object)

# %%
data['Inbuilt Heater'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['Maximum Spin Speed'].unique()
# Out:
# array(['680 rpm', '1400 RPM', '700 rpm', '1350 rpm', '1000 rpm',
#        '800 rpm', '1300 rpm', '1350 RPM', '740 rpm', '1200 rpm',
#        '1400 rpm', '720 rpm'], dtype=object)

# %%
data['Model Name'].unique()
# Out:
# array(['WA70A4002GS/TL', 'RMSA705NNNDW', 'RMFA75A5G', 'P7020NGAZ',
#        'WW60R20GLMA/TL', 'HWM65-FE', 'WA70BG4441YYTL', 'HTW85-186',
#        'MQSA60H5M', 'RMSA855NNNDG', 'MAGIC CLEAN 7.0 GENX GREY 5YMW',
#        'HTW90-1159', 'T70SKSF1Z', 'MAGIC CLEAN 6.0 GENX GREY 5YMW',
#        'MQSA70H5M', 'WA90BG4542BDTL', 'DIVA AQUA VSS 6008', 'S70GR',
#        'RMSA755NNNDG', 'WA80BG4441BGTL', 'WT60R2000LL/TL',
#        'Senator Neo VXS 8012', 'FHM1207SDM', 'WA65T4262NS/TL',
#        'HTW65-187BO', 'WA65T4262GG/TL', 'WT70M3000UU/TL',
#        'MAGIC CLEAN 60I GREY DAZZLE',
#        'MAGIC CLEAN 8.0 GREY DAZZLE (10YR) NH', 'T62CGN / CRYSTAL 62',
#        'TL-R1WH 7.0KG AQUA', 'MF100W70/T-IN', 'MA100W70/G-IN'],
#       dtype=object)

# %%
data['Price'].unique()
# Out:
# array(['₹15,790', '₹7,790', '₹12,290', '₹11,990', '₹22,990', '₹12,990',
#        '₹17,990', '₹12,690', '₹6,790', '₹9,990', '₹15,240', '₹13,990',
#        '₹17,490', '₹13,690', '₹7,190', '₹25,090', '₹21,990', '₹7,990',
#        '₹8,690', '₹19,990', '₹8,990', '₹31,990', '₹29,990', '₹16,990',
#        '₹8,950', '₹15,990', '₹10,990', '₹12,490', '₹13,190'], dtype=object)

# %%
data['Ratings'].unique()
# Out:
# array([4.3, 4.2, 4.5, 4.4, 4. ])

# %%
data['Washing Capacity'].unique()
# Out:
# array(['7 kg', '7.5 kg', '6 kg', '6.5 kg', '8.5 kg', '9 kg', '8 kg',
#        '6.2 kg'], dtype=object)

# %%
data['Washing Method'].unique()
# Out:
# array(['Pulsator', 'Normal Pulsator Wash', 'Tumble', 'Gentle',
#        'Agipellar', 'Dual Color Vortex Pulsator Wash', 'Tumble Wash',
#        'Agitator', 'Impeller', 'Pulsator Wash', 'Triadic Pulsator'],
#       dtype=object)

# %%
data = data.drop(columns= ['Product Name','Product_Url'])

# %%
data
# Out:
#         Price  Ratings       Brand Name                   Model Name  \
# 0     ₹15,790      4.3          SAMSUNG               WA70A4002GS/TL
# 1      ₹7,790      4.2  realme TechLife                 RMSA705NNNDW
# 2     ₹12,290      4.2  realme TechLife                    RMFA75A5G
# 3     ₹11,990      4.5               LG                    P7020NGAZ
# 4     ₹22,990      4.4          SAMSUNG               WW60R20GLMA/TL
# ...       ...      ...              ...                          ...
# 1051  ₹19,990      4.3          SAMSUNG               WA80BG4441BGTL
# 1052   ₹8,990      4.4          SAMSUNG               WT60R2000LL/TL
# 1053   ₹7,990      4.2            ONIDA                        S70GR
# 1054   ₹8,990      4.4        Whirlpool  MAGIC CLEAN 60I GREY DAZZLE
# 1055  ₹16,990      4.4          SAMSUNG               WA65T4262NS/TL
#
#      Washing Capacity                Color Maximum Spin Speed  \
# 0                7 kg               Silver            680 rpm
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Price               1056 non-null   object
#  1   Ratings             1056 non-null   float64
#  2   Brand Name          1056 non-null   object
#  3   Model Name          1056 non-null   object
#  4   Washing Capacity    1056 non-null   object
#  5   Color               1056 non-null   object
#  6   Maximum Spin Speed  1056 non-null   object
#  7   Function Type       1056 non-null   object
#  8   Inbuilt Heater      1056 non-null   object
#  9   Washing Method      1056 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 82.6+ KB

# %%
data["Inbuilt Heater"] = data["Inbuilt Heater"].map({"Yes": 1, "No": 0})

# %%
data['Inbuilt Heater'] = data['Inbuilt Heater'].astype(int)

# %%
data
# Out:
#         Price  Ratings       Brand Name                   Model Name  \
# 0     15790.0      4.3          SAMSUNG               WA70A4002GS/TL
# 1      7790.0      4.2  realme TechLife                 RMSA705NNNDW
# 2     12290.0      4.2  realme TechLife                    RMFA75A5G
# 3     11990.0      4.5               LG                    P7020NGAZ
# 4     22990.0      4.4          SAMSUNG               WW60R20GLMA/TL
# ...       ...      ...              ...                          ...
# 1051  19990.0      4.3          SAMSUNG               WA80BG4441BGTL
# 1052   8990.0      4.4          SAMSUNG               WT60R2000LL/TL
# 1053   7990.0      4.2            ONIDA                        S70GR
# 1054   8990.0      4.4        Whirlpool  MAGIC CLEAN 60I GREY DAZZLE
# 1055  16990.0      4.4          SAMSUNG               WA65T4262NS/TL
#
#       Washing Capacity                Color Maximum Spin Speed  \
# 0                  7.0               Silver            680 rpm
# ...

# %%
data['Price'] = data['Price'].str.replace(r"[₹,]" , "",regex= True).astype(float)

# %%
data['Washing Capacity'] = data['Washing Capacity'].str.replace('kg',"",regex=True).astype(float)

# %%
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Price               1056 non-null   float64
#  1   Ratings             1056 non-null   float64
#  2   Brand Name          1056 non-null   object
#  3   Model Name          1056 non-null   object
#  4   Washing Capacity    1056 non-null   float64
#  5   Color               1056 non-null   object
#  6   Maximum Spin Speed  1056 non-null   object
#  7   Function Type       1056 non-null   object
#  8   Inbuilt Heater      1056 non-null   int64
#  9   Washing Method      1056 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 82.6+ KB

# %%
data['Maximum Spin Speed'] = data['Maximum Spin Speed'].str.replace(r'[rR][pP][mM]',"",regex= True).astype(int)d

# %%
data
# Out:
#         Price  Ratings       Brand Name                   Model Name  \
# 0     15790.0      4.3          SAMSUNG               WA70A4002GS/TL
# 1      7790.0      4.2  realme TechLife                 RMSA705NNNDW
# 2     12290.0      4.2  realme TechLife                    RMFA75A5G
# 3     11990.0      4.5               LG                    P7020NGAZ
# 4     22990.0      4.4          SAMSUNG               WW60R20GLMA/TL
# ...       ...      ...              ...                          ...
# 1051  19990.0      4.3          SAMSUNG               WA80BG4441BGTL
# 1052   8990.0      4.4          SAMSUNG               WT60R2000LL/TL
# 1053   7990.0      4.2            ONIDA                        S70GR
# 1054   8990.0      4.4        Whirlpool  MAGIC CLEAN 60I GREY DAZZLE
# 1055  16990.0      4.4          SAMSUNG               WA65T4262NS/TL
#
#       Washing Capacity                Color  Maximum Spin Speed  \
# 0                  7.0               Silver                 680
# ...

# %%
data = data.rename( columns={ 
     "Price" :"Price in Rupees",
     "Washing Capacity" :"Washing Capacity in kg",
     "Maximum Spin Speed" :"Maximum Spin Speed in RPM"
})

# %%
data
# Out:
#       Price in Rupees  Ratings       Brand Name                   Model Name  \
# 0             15790.0      4.3          SAMSUNG               WA70A4002GS/TL
# 1              7790.0      4.2  realme TechLife                 RMSA705NNNDW
# 2             12290.0      4.2  realme TechLife                    RMFA75A5G
# 3             11990.0      4.5               LG                    P7020NGAZ
# 4             22990.0      4.4          SAMSUNG               WW60R20GLMA/TL
# ...               ...      ...              ...                          ...
# 1051          19990.0      4.3          SAMSUNG               WA80BG4441BGTL
# 1052           8990.0      4.4          SAMSUNG               WT60R2000LL/TL
# 1053           7990.0      4.2            ONIDA                        S70GR
# 1054           8990.0      4.4        Whirlpool  MAGIC CLEAN 60I GREY DAZZLE
# 1055          16990.0      4.4          SAMSUNG               WA65T4262NS/TL
#
# ...

# %%
data.to_excel(r'C:\Users\Hemanth2512005\Desktop\Washing_machine_Sql project\exported_data.xlsx', sheet_name='Sheet1', index=False)
